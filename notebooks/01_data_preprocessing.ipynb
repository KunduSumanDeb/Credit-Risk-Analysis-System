# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from src.config import CREDIT_RISK_DATASET
from src.preprocessing import *

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# d:\Projects\Credit-Risk-Analysis-System\notebooks

# %%
# ============================================================================
# Project Path Setup
# ============================================================================

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.config import CREDIT_RISK_DATASET
from src.preprocessing import load_dataset

df = load_dataset(CREDIT_RISK_DATASET)

df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
rows, columns = get_dataset_shape(df)

print(f"Rows    : {rows}")
print(f"Columns : {columns}")
# Out:
# Rows    : 32581
# Columns : 12

# %%
head, tail = display_sample_records(df)

display(head)
display(tail)
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
column_information = get_column_information(df)

display(column_information)
# Out:
#                         Column Data Type  Non-Null Count  Missing Values  \
# 0                   person_age     int64           32581               0
# 1                person_income     int64           32581               0
# 2        person_home_ownership       str           32581               0
# 3            person_emp_length   float64           31686             895
# 4                  loan_intent       str           32581               0
# 5                   loan_grade       str           32581               0
# 6                    loan_amnt     int64           32581               0
# 7                loan_int_rate   float64           29465            3116
# 8                  loan_status     int64           32581               0
# 9          loan_percent_income   float64           32581               0
# 10   cb_person_default_on_file       str           32581               0
# 11  cb_person_cred_hist_length     int64           32581               0
#
#     Unique Values
# ...

# %%
missing_values = check_missing_values(df)

display(missing_values)
# Out:
#                    Missing Values  Missing Percentage
# loan_int_rate                3116                9.56
# person_emp_length             895                2.75

# %%
duplicate_records = check_duplicate_records(df)

print(f"Duplicate Records : {duplicate_records}")
# Out:
# Duplicate Records : 165

# %%
memory_usage = get_memory_usage(df)

print(f"Memory Usage : {memory_usage:.2f} MB")
# Out:
# Memory Usage : 8.63 MB

# %%
dataset_summary = generate_dataset_summary(df)

dataset_summary
# Out:
# {'Rows': 32581,
#  'Columns': 12,
#  'Numerical Columns': 8,
#  'Categorical Columns': 4,
#  'Duplicate Rows': 165,
#  'Memory Usage (MB)': 8.63}

# %%
numerical_summary = get_numerical_summary(df)

display(numerical_summary)
# Out:
#                               count          mean           std      min  \
# person_age                  32581.0     27.734600      6.348078    20.00
# person_income               32581.0  66074.848470  61983.119168  4000.00
# person_emp_length           31686.0      4.789686      4.142630     0.00
# loan_amnt                   32581.0   9589.371106   6322.086646   500.00
# loan_int_rate               29465.0     11.011695      3.240459     5.42
# loan_status                 32581.0      0.218164      0.413006     0.00
# loan_percent_income         32581.0      0.170203      0.106782     0.00
# cb_person_cred_hist_length  32581.0      5.804211      4.055001     2.00
#
#                                  25%       50%       75%         max
# person_age                     23.00     26.00     30.00      144.00
# person_income               38500.00  55000.00  79200.00  6000000.00
# person_emp_length               2.00      4.00      7.00      123.00
# ...

# %%
categorical_summary = get_categorical_summary(df)

display(categorical_summary)
# Out:
#                            count unique        top   freq
# person_home_ownership      32581      4       RENT  16446
# loan_intent                32581      6  EDUCATION   6453
# loan_grade                 32581      7          A  10777
# cb_person_default_on_file  32581      2          N  26836

# %%
duplicate_records = get_duplicate_records(df)

display(duplicate_records.head(10))
# Out:
#       person_age  person_income person_home_ownership  person_emp_length  \
# 14            23         115000                  RENT                2.0
# 238           22         183000              MORTGAGE                3.0
# 252           24          85000                  RENT                5.0
# 591           26          20000              MORTGAGE                5.0
# 740           21          21600                   OWN                NaN
# 817           22          22000                   OWN                1.0
# 920           26          50000                  RENT               10.0
# 1094          22          24449                   OWN                2.0
# 1142          25          60000                  RENT                3.0
# 1453          23          20400                  RENT                2.0
#
#             loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 14            EDUCATION          A      35000           7.90            0
# ...

# %%
validation_report = validate_dataset(df)

validation_report
# Out:
# {'Dataset Empty': False,
#  'Contains Missing Values': True,
#  'Contains Duplicates': True,
#  'Total Missing Values': 4011,
#  'Total Duplicate Rows': 165,
#  'Validation Status': 'Passed'}

# %%
print("Before :", df.shape)

cleaned_df = remove_duplicate_records(df)

print("After  :", cleaned_df.shape)
# Out:
# Before : (32581, 12)
# After  : (32416, 12)

# %%
check_duplicate_records(cleaned_df)
# Out:
# np.int64(0)

# %%
missing_report = analyze_missing_values(cleaned_df)

display(missing_report)
# Out:
#                    Missing Values  Missing Percentage Data Type
# loan_int_rate                3095                9.55   float64
# person_emp_length             887                2.74   float64

# %%
filled_df = fill_missing_values(cleaned_df)

check_missing_values(filled_df)
# Out:
# Empty DataFrame
# Columns: [Missing Values, Missing Percentage]
# Index: []

# %%
data_types = validate_data_types(filled_df)

display(data_types)
# Out:
#                                                 Column Data Type
# person_age                                  person_age     int64
# person_income                            person_income     int64
# person_home_ownership            person_home_ownership       str
# person_emp_length                    person_emp_length   float64
# loan_intent                                loan_intent       str
# loan_grade                                  loan_grade       str
# loan_amnt                                    loan_amnt     int64
# loan_int_rate                            loan_int_rate   float64
# loan_status                                loan_status     int64
# loan_percent_income                loan_percent_income   float64
# cb_person_default_on_file    cb_person_default_on_file       str
# cb_person_cred_hist_length  cb_person_cred_hist_length     int64

# %%
from src.config import INTERIM_DATA_DIR

save_cleaned_dataset(
    filled_df,
    INTERIM_DATA_DIR / "cleaned_data.csv"
)

# %%
import os

os.path.exists(
    INTERIM_DATA_DIR / "cleaned_data.csv"
)
# Out:
# True
